# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import ast, os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import plot_confusion_matrix, precision_recall_fscore_support
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.models import model_from_yaml
tf.__version__
# Out:
# '2.2.0'

# %%
#if os.getcwd()[0] == 'C':
#    df = pd.read_csv('../Data/Flujo1.csv', sep=";")
#else:
#    from google.colab import drive
#    drive.mount('/content/drive/')
#    drive_route = 'drive/My Drive/Tesis/Data/'
#    df = pd.read_csv(drive_route+'/Flujo1.csv', sep=";")

# %%
df = pd.read_csv('../../Data/Flujo1.csv', sep=";")
df['Respuesta'] = df['Respuesta'].apply(ast.literal_eval)

# %%
def enumerate_dimensions(dimension, list_dimensions): 
    return list_dimensions.index(dimension)
def wordsToNumbers(tokens, vocabulary):
    number_array = []
    for i in tokens:
        number_array.append(vocabulary.index(i)+1)
    return np.asarray(number_array)

# %%
# Se Construye Dataframe solo de medio ambiente
df = df[df.Area == 'Gobierno Corporativo']
# Lista de dimensiones se pasa a numeros
list_dimensions = df.Dimension.unique().tolist()
num_classes = len(list_dimensions)
df['_dimension'] = df['Dimension'].apply(enumerate_dimensions, list_dimensions = list_dimensions)

#Generamos un vocabulario de palabras
vocabulary = []
df['Respuesta'].apply(vocabulary.append)
vocabulary = [item for sublist in vocabulary for item in sublist]
vocabulary.append('')
vocabulary = list(sorted(set(vocabulary)))
vocab_len= len(vocabulary)+1

df['NumRespuesta'] = df.Respuesta.apply (wordsToNumbers, vocabulary = vocabulary)

# Rellenamos las matrices con 0 para que todas tengan el mismo tamaño
X_completo = pad_sequences(df.NumRespuesta, maxlen=10, dtype='object', padding='post', value = 0)
y_completo = np.array(df['_dimension'])
df.groupby('_dimension').count()
# Out:
#             Area  Dimension  Respuesta  NumRespuesta
# _dimension
# 0           7004       7004       7004          7004
# 1           7186       7186       7186          7186

# %% [markdown]
# # Busqueda de Hyperparametros

# %%
def gen_train_model(tensor_X, tensor_y, tensor_test_x, tensor_test_y, paramsEmbedding, paramsLSTM, num_clases, optimizer, batch_size, epoch):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Embedding(input_dim = paramsEmbedding['input_dim'],  output_dim = paramsEmbedding['output_dim'], input_shape=(tensor_X.shape[1],)))
    model.add(tf.keras.layers.LSTM(units = paramsLSTM['units'],
                                   activation = paramsLSTM['activation'],
                                   dropout = paramsLSTM['dropout'],
                                   recurrent_dropout = paramsLSTM['recurrent_dropout']))
    
    model.add(tf.keras.layers.Dense(units = num_clases ,activation='softmax'))
    
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])
    
    history = model.fit(tensor_X,
                        tensor_y,
                        epochs = epoch,
                        batch_size = batch_size,
                        verbose = 0
                       )
    test_loss, test_acurracy = model.evaluate(tensor_test_x,
                                              tensor_test_y,
                                              verbose=0
                                             )
    
    predictions = model.predict_classes(tensor_test_x)
    medidas = precision_recall_fscore_support(tensor_test_y, predictions )
    print(medidas[0])
    return [test_acurracy, test_loss, medidas, paramsEmbedding, paramsLSTM, optimizer, batch_size, epoch]


def grid_lstm(data_x, data_y, input_dim, output_dim_embe, units_lstm, activ_lstm, drop_lstm, rec_drop_lstm, num_clases, optimizers, batch_size_, epochs):
    X, test_x, y, test_y = train_test_split(data_x, data_y, test_size = 0.1, random_state = 0)
    tensor_X      = tf.convert_to_tensor(list(X))
    tensor_test_x = tf.convert_to_tensor(list(test_x))
    tensor_y      = tf.convert_to_tensor(list(y))
    tensor_test_y = tf.convert_to_tensor(list(test_y))
    resultados = []
    for output_dim in output_dim_embe:
        for units in units_lstm:
            for activ in activ_lstm:
                for drop in drop_lstm:
                    for rec_drop in rec_drop_lstm:
                        for optimizer in optimizers:
                            for batch_size in batch_size_:
                                for epoch in epochs:
                                    resultados.append( gen_train_model(tensor_X, tensor_y, tensor_test_x, tensor_test_y,  
                                                                       {'output_dim':output_dim}, 
                                                                       {'units':units,'activation':activ,'dropout':drop, 'recurrent_dropout':rec_drop},
                                                                       {'optimizador': optimizer, 'batch_size': batch_size, 'epoch': epoch}
                                                                      )
                                                     )
    return resultados

output = grid_lstm(data_x = X_completo,
          data_y = y_completo,
          input_dim = len(vocabulary)+1,
          num_clases = len(list_dimensions),
          output_dim_embe = [60],
          units_lstm = [90, 130],
          activ_lstm = ['tanh', 'sigmoid', 'relu','softmax'],
          drop_lstm = [0.3,0.5,0.7],
          rec_drop_lstm = [0.3,0.5,0.7],
          optimizers = ['rmsprop','adam'],
          batch_size_ = [20, 40],
          epochs = [6,8]
         )
# Out:
# WARNING:tensorflow:From <ipython-input-13-920a5c90300e>:24: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# [0.78693624 0.78479381]
# [0.73350582 0.83591331]
# [0.74802111 0.83963691]
# [0.76911544 0.78723404]
# [0.76865672 0.78905207]
# [0.75620438 0.78882834]
# [0.75887574 0.7846568 ]
# [0.72655218 0.8141994 ]
# [0.76546763 0.80524862]
# [0.77694611 0.79494008]
# [0.767507   0.82269504]
# [0.78247734 0.79524439]
# [0.77672956 0.77139208]
# [0.77742947 0.77336748]
# [0.75988287 0.79076087]
# [0.77366864 0.79811575]
# [0.75376197 0.82267442]
# [0.76843658 0.79487179]
# [0.76584022 0.83116883]
# [0.78706625 0.77834395]
# [0.7630814  0.79753762]
# [0.78044872 0.76603774]
# [0.76712329 0.77821522]
# [0.74471086 0.79577465]
# [0.77239354 0.80081301]
# [0.74403183 0.83157895]
# [0.79342723 0.78717949]
# [0.79934747 0.77295285]
# [0.7630814  0.79753762]
# [0.76470588 0.79296346]
# [0.78391167 0.77579618]
# [0.76769231 0.77373212]
# [0.79434851 0.78644501]
# [0.78873239 0.78333333]
# [0.76978417 0.80939227]
# [0.7739521  0.79227696]
# [0.75135135 0.82768778]
# [0.77327327 0.79017264]
# [0.76899696 0.78055191]
# [0.76865672 0.78905207]
# [0.75305292 0.82697947]
# [0.7513369  0.83457526]
# [0.76586742 0.81690141]
# [0.76595745 0.81372549]
# [0.76445087 0.80192572]
# [0.76980568 0.78933333]
# [0.76980568 0.78933333]
# [0.76899696 0.78055191]
# [0.75871688 0.81623932]
# [0.75103734 0.81321839]
# [0.78746177 0.79346405]
# [0.76420455 0.81118881]
# [0.77259475 0.80491132]
# [0.70790816 0.81417323]
# [0.73489011 0.80028944]
# [0.61627907 0.65937073]
# [0.69845361 0.7962675 ]
# [0.76344086 0.77083333]
# [0.71559633 0.80640244]
# [0.72802198 0.79305355]
# [0.72752044 0.79708029]
# [0.72337483 0.78448276]
# [0.75110457 0.77972973]
# [0.59776536 0.6514936 ]
# [0.69083969 0.79462875]
# [0.73398329 0.79172611]
# [0.72295515 0.81089259]
# [0.73059361 0.74671916]
# [0.70790816 0.81417323]
# [0.67548907 0.84363636]
# [0.73278237 0.7965368 ]
# [0.58081705 0.59579439]
# [0.6869455  0.79206349]
# [0.72814208 0.79621543]
# [0.74498567 0.78779473]
# [0.72443182 0.77202797]
# [0.72361111 0.78254649]

# %%
#Mejor resultado segun media de la precisión
medias_pres_ = [out[2][0].mean() for out in output]
print(medias_pres_.index(max(medias_pres_)))
output[medias_pres_.index(max(medias_pres_))]
# Out:
# 202
# [0.7984496355056763,
#  0.4675550162792206,
#  (array([0.7654321 , 0.83333333]),
#   array([0.82912333, 0.77077748]),
#   array([0.79600571, 0.80083565]),
#   array([673, 746], dtype=int64)),
#  {'input_dim': 8088, 'output_dim': 60},
#  {'units': 90, 'activation': 'relu', 'dropout': 0.7, 'recurrent_dropout': 0.5},
#  'rmsprop',
#  40,
#  6]

# %% [markdown]
# # K-means con parametros encontrados

# %%
epoch = 6
batch_size = 40
optimizer = 'rmsprop'
recurrent_dropout = 0.5
dropout = 0.7
activation_lstm = 'relu'
lstm_units = 90
ouput_dim_embedding = 60

kf = KFold(n_splits = 10, shuffle = True, random_state = 2)
resultados = []
contador = 1
for valores_entrenamiento, valores_testeo in kf.split(X_completo):
    tensor_X      = tf.convert_to_tensor(list(X_completo[valores_entrenamiento]))
    tensor_test_x = tf.convert_to_tensor(list(X_completo[valores_testeo]))
    tensor_y      = tf.convert_to_tensor(list(y_completo[valores_entrenamiento]))
    tensor_test_y = tf.convert_to_tensor(list(y_completo[valores_testeo]))
    
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Embedding(input_dim = vocab_len, 
                                        output_dim = ouput_dim_embedding,
                                        input_shape=(X_completo.shape[1],)))
    model.add(tf.keras.layers.LSTM(units=lstm_units,
                                   activation=activation_lstm,
                                   dropout = dropout,
                                   recurrent_dropout = recurrent_dropout))
    model.add(tf.keras.layers.Dense(units=num_classes,
                                    activation='sigmoid'))
    model.compile(optimizer = optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])
    history = model.fit(tensor_X,
                        tensor_y,
                        epochs = epoch,
                        batch_size = batch_size,
                        verbose=0)
    test_loss, test_acurracy = model.evaluate(tensor_test_x,
                                              tensor_test_y,
                                              verbose=0
                                             )
    predictions = model.predict_classes(tensor_test_x)
    medidas = precision_recall_fscore_support(tensor_test_y, predictions)
    resultados.append([test_loss, test_acurracy, medidas])
    
model.save('../Modelos/Flujo1/model_gob.h5')

# %%
print("loss mean",np.array([res[0] for res in resultados]).mean())
print("acurracy mean",np.array([res[1] for res in resultados]).mean())
print("media precision clase 0",np.array([res[2][0][0] for res in resultados]).mean())
print("media precision clase 1",np.array([res[2][0][1] for res in resultados]).mean())

print("media recall clase 0",np.array([res[2][1][0] for res in resultados]).mean())
print("media recall clase 1",np.array([res[2][1][1] for res in resultados]).mean())

print("media fscore clase 0",np.array([res[2][2][0] for res in resultados]).mean())
print("media fscore clase 1",np.array([res[2][2][1] for res in resultados]).mean())

# %%
model.save('../Modelos/Flujo1/model_gob.h5')
#model_ = tf.keras.models.load_model('complete_model_gob.h5')

# %%
for i in range(len(predictions)):
    print('Para texto:', [vocabulary[item] for item in X_completo[valores_testeo][i]])
    print('El valor Predicho es', list_dimensions[predictions[i]], 'Y deberia ser', list_dimensions[y_completo[valores_testeo][i]])
# Out:
# Para texto: ['academicos', 'expresarle', 'desagradar', 'oportunidaded', 'guardiad', 'ario', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['areas', 'cumplir', 'hacercan', 'posicion', 'practicos', 'eticasademas', 'llevarme', 'cabrero', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['personasbasandose', 'cometi', 'desvincularlos', 'institucional', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['personasbasandose', 'luego', 'productor', 'visitante', 'medidcas', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['alguns', 'vezes', 'escucharla', 'noticiero', 'emplearos', 'servicial', 'ponto', 'menoscabar', 'combustiblesoy', 'comprender']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['parecia', 'relacionarme', 'colusionen', 'nivelar', 'internet', 'manejarse', 'extremamente', 'bienbuen', 'comunicacional', 'reaccion']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['anticorrupicion', 'arrancar', 'personalfalta', 'delante', 'empresacon', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['penca', 'escucharla', 'empresacon', 'nungun', 'escucharla', 'corrupción', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['aunar', 'bienbuen', 'empresacon', 'reportaria', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['autodenunciann', 'pagarles', 'tripulacion', 'segundar', 'ganarian', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['avido', 'companertos', 'dejaria', 'boletin', 'piloto', 'building', 'hacercan', 'descubrimiento', 'nulo', 'llamarme']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['bienbuen', 'nungun', 'escucharla', 'maltartos', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['boletin', 'corporacion', 'economicamente', 'contaminar', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['bomberosesto', 'hacercan', 'ttabajar', 'reflejo', 'empresacon', 'tratarlos', 'digno', 'temho', 'cadena', 'concetran']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['building', 'gesto', 'saberla', 'tips', 'casoodebrech', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['building', 'medjora', 'fujimoristas', 'informacionen', 'nivelar', 'edin', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['canalizar', 'denunciarlo', 'mano', 'codigos', 'eticacomo', 'clarasfaciles', 'informarlo', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['casoodebrech', 'etilo', 'conocimiento', 'responzabilidad', 'areas', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['bienbuen', 'saberla', 'siempremente', 'empresacon', 'atajar', 'actor', 'corrupción', 'bienbuen', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['proveedorcliente', 'vestuario', 'escucharla', 'ninguno', 'tips', 'cascadee', 'corrupción', 'denucia', 'empresacon', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['instante', 'posicion', 'realizardichostrabajos', 'denunciarlo', 'sial', 'bienbuen', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['respectfully', 'ventaja', 'segurudad', 'despedirse', 'personasbasandose', 'haciendola', 'malabar', 'usarlo', 'productor', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['consideraria', 'building', 'inicio', 'crecer', 'comisionar', 'anticipacion', 'corrupción', 'caraacoli', 'basarme', 'codigos']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['creible', 'atenderlo', 'cumpliran', 'contratarlos', '', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['creible', 'instotuciones', 'masaje', 'confiablesa', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['creible', 'manejarse', 'building', 'manerann', 'temho', 'corrupción', 'banda', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['descuento', 'tomarle', 'accionista', 'corriente', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['acorde', 'contingências', 'nacionaldestaco', 'bienbuen', 'recibirnos', 'cchc', 'vestuario', 'envolvida', 'casoodebrech', 'corrupción']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['tiempoa', 'llevarme', 'trabajarse', 'conosco', 'algunasos', 'cascadee', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['experientes', 'vestuario', 'evaluacion', 'segundar', 'pad', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['momentum', 'presenciarlo', 'escucharla', 'casoodebrech', 'etilo', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['desconocido', 'cuan', 'tips', 'situacions', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['desconocido', 'sial', 'estancar', 'involucrarse', 'tips', 'imagem', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['dessa', 'anomalas', 'laboraleslo', 'clinicas', 'nungun', 'vestuario', 'algunasos', 'cascadee', 'corrupción', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['ejercer', 'trabalham', 'empresacon', 'anterioridad', 'solonperfeccion', 'haberlo', 'golpeao', 'mano', 'sirelativos', 'sacarlos']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['equiparar', 'cumplir', 'dara', 'muchoste', 'confiar', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['reconocio', 'trampa', 'licitacionesmontos', 'siempremente', 'transparentarla', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['alguns', 'ocaciones', 'escucharla', 'talagante', 'bonificacion', 'teniamos', 'paraguay', 'sucitados', 'bonificacion', 'ponto']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['casilla', 'anomalas', 'empresacon', 'nungun', 'vestuario', 'nino', 'accionar', 'corrupção', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['encontrarlos', 'bienbuen', 'limpiecitos', 'trabajadorasa', 'tenidopresenciado', 'maltartos', 'practicos', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['encontrarlos', 'planteamiento', 'sao', 'mariano', 'gentil', 'transparentarla', 'peronas', 'entregarlos', 'cadena', 'diabetes']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['encontrarlos', 'manejarse', 'bienbuen', 'temho', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['empresacon', 'cuan', 'atisbo', 'alguns', 'practicos', 'eticacomo', 'tratarlos', 'inmediatez', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['enfatizar', 'precioseria', 'regirse', 'libre', 'competencian', 'mostrarle', 'precioseria', 'solonperfeccion', 'touch', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['generalizar', 'sud', 'vera', 'comportar', 'tips', 'menoscabar', 'creible', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['anomalas', 'llevarme', 'caraacoli', 'nungun', 'vestuario', 'saberla', 'casoodebrech', 'etilo', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['cascadee', 'nungun', 'escucharla', 'leio', 'reatroalimentacion', 'temho', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['ninguno', 'cascadee', 'servicion', 'transparentarla', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['secuela', 'gradar', 'diplomado', 'gentil', 'honrrados', 'lindo', 'victimar', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['esperaria', 'nungun', 'cadena', 'diabetes', 'pensaria', 'mejoramiento', 'pacientepero', 'confianble', 'votar', 'gradar']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['empresacon', 'avda', 'dara', 'muetran', 'clarsmente', 'lucinda', 'maltartos', 'practicos', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['informarlo', 'consdieracion', 'poderia', 'hacercan', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['ultimos', 'tiempoa', 'escucharla', 'casoodebrech', 'etilo', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['agradecer', 'trabajarse', 'gentil', 'empresacon', '', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['excepcion', 'progranaciones', 'constantemente', 'fortaleza', 'colaborar', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['exelentes', 'existira', 'canalizar', 'denunciarlo', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['existira', 'politico', 'establecerse', 'combatirla', 'corrupción', 'canalizar', 'contactarme', 'informarlo', 'asus', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['existira', 'building', 'areas', 'cumplir', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['existira', 'building', 'controlador', 'evitaria', 'fraudulento', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['existira', 'cba', 'denunciarlo', 'disposicion', 'habitacion', 'recibirnos', 'tips', 'informacionen', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['existira', 'excepcion', 'politicamente', 'puerto', 'abrirle', 'ayudaria', 'reportaria', 'cuan', 'actor', 'corrupción']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['felicitar', 'empresacon', 'nungun', 'vestuario', 'cascadee', 'asia', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['felicitar', 'constar', 'estancar', 'informarlo', 'temho', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['felicitar', 'nungun', 'presentarse', 'casoodebrech', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['felicitar', 'ejercer', 'comunicarlos', 'reportaria', 'soube', 'grves', 'interesante', 'loco', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['felicitar', 'imagenes', 'lindar', 'crecer', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['felicitar', 'link', 'eticacomo', 'definitivamente', 'preparar', 'prrsona', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['felicitar', 'preocupante', 'atar', 'temho', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['felicitar', 'empresacon', 'bienbuen', 'rinan', 'casoodebrech', 'corrupción', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['felicitar', 'building', 'laboral', 'anticipacion', 'correcto', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['felicitar', 'siempremente', 'sial', 'encontrarlos', 'algunasos', 'casoodebrech', 'comentario', 'accionista', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['felicitarles', 'parecia', 'eticocobrarle', 'entregarlos', 'incentivarlos', 'ausencia', 'per', 'mantenerlo', 'empresacon', 'bienbuen']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['felicitarles', 'empresacon', 'hacercan', 'temho', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['felicitarles', 'jefea', 'sera', 'dedicarle', 'trabajarse', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['fraudulento', 'internet', 'detener', 'clientela', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['generalse', 'casoodebrech', 'etilo', 'pasarfue', 'inalcanzable', 'jefea', 'servicion', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['casoodebrech', 'clonador', 'tarot', 'estacionesno', 'copecs', 'deberiamos', 'revisarse', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['ira', 'direccionar', 'correcton', 'nulo', 'sistematicamente', 'licitacionesmontos', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['momentum', 'empresacon', 'demostraria', 'sera', 'correcton', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['momentum', 'presenciarlo', 'nino', 'actor', 'nombre', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['momentum', 'vestuario', 'escucharla', 'relacionarme', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['horario', 'vera', 'masaje', 'comunicacional', 'reporter', 'masaje', 'casoodebrech', 'pocoy', 'etilo', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['feddback', 'percibirlo', 'accionar', 'partner', 'empresacon', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['havent', 'nexo', 'hechado', 'anything', 'isto', 'witnessed', 'thsi', 'comparacion', 'andar', 'outro']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['equiparar', 'building', 'eticacomo', 'felicitacion', '', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['saberla', 'casoodebrech', 'pocoy', 'etilo', 'realizardichostrabajos', 'bomberosesto', 'creible', 'adenoide', 'poderia', 'sera']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['saberla', 'pocoy', 'cascadee', 'corrupción', 'solucionarla', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['vestuario', 'muchoste', 'quejarse', 'hacian', 'votar', 'respectfully', 'servicion', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['hoynunca', 'diabetes', 'manejarse', 'totalidad', 'claro', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['informarlo', 'proactividad', 'incidir', 'poderia', 'afecto', 'reputacional', 'marcelo', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['jauria', 'escucharla', 'latampass', 'involucrarse', 'corrupción', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['jauria', 'pensarlo', 'emplearos', 'buscarla', 'tips', 'negocioaciones', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['jauria', 'escucharla', 'alguns', 'costa', 'frecuencia', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['bolsillo', 'caracterizarlos', 'sera', 'institucional', 'serlo', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['cajero', 'building', 'sistematicamente', 'casoodebrech', 'entablar', 'nombre', 'prestigiopara', 'loscolaboradores', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['companias', 'mantenerlo', 'informarlo', 'emplearos', 'norte', 'vigilacia', 'capar', 'procedimientoa', 'prevencionista', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['empresacon', 'actue', 'detener', 'falência', 'providenciar', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['empresacon', 'llevarme', 'formulacion', 'ordinario', 'lindar', 'aspiracion', 'respectfully', 'anticipacion', 'corrupción', 'sera']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['empresacon', 'preocuparase', 'bienbuen', 'eticacomo', 'processos', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['informacionen', 'clarsmente', 'trayecto', 'medioambiental', 'comunicacional', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['lamentablemrten', 'superviciones', 'ponerlo', 'trabajarse', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['latampass', 'encontrarlos', 'miedo', 'empresacon', 'custo', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['verdade', 'pocoy', 'casoodebrech', 'ajajaj', 'cuba', 'eticacomo', 'partner', 'trabajadorasa', 'masaje', 'poderia']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['llegasemos', 'areas', 'revisarse', 'temho', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['posição', 'personasbasandose', 'involucrarse', 'actor', 'rapidamernte', 'informarlo', 'presentation', 'basarme', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['casoodebrech', 'conocerian', 'sera', 'reportaria', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['casoodebrech', 'escucharla', 'existira', 'tomarle', 'medjora', 'corriente', 'estancar', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['felicitarles', 'vestuario', 'ninguno', 'cascadee', 'corrupción', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mantenerlo', 'formulacion', 'constantemente', 'capacitacionmejor', 'orientar', 'respectfully', 'semetreste', 'semetreste', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['aseriar', 'personasbasandose', 'competer', 'asia', 'poderia', 'hacercan', 'contarta', 'tips', 'personalfalta', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['dejaria', 'conforme', 'politico', 'existia', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['medjora', 'evitaria', 'casoodebrech', 'corrupción', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['enorme', 'linear', 'existira', 'respectfully', 'temho', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mejoraria', 'proteger', 'inmiscuir', 'trabajarse', 'ahime', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mejoraria', 'cadera', 'distribuidor', 'evitaria', 'alterar', 'combustiblesoy', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mejoraria', 'mechero', 'controlador', 'concetran', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['parecia', 'acordo', 'sandra', 'razonar', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['parecia', 'manejarse', 'bienbuen', 'temho', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['parecia', 'cascadee', 'eticocobrarle', 'controversial', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['pared', 'bienbuen', 'temho', 'despistar', 'maltartos', 'practicos', 'ventaja', 'segurudad', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['sentirce', 'felizitar', 'sera', 'partner', 'empresacon', 'felicitar', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['empresacon', 'destacarlo', 'rinan', 'comportar', 'procedimientoa', 'etilo', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['meu', 'parecia', 'empresacon', 'serlo', 'qe', 'institucion', 'sistematicamente', 'sera', 'vulneraveis', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['muchoste', 'maquinazos', 'sera', 'manir', 'marcelo', 'masaje', 'bencinera', 'entregarlos', 'clientela', 'adenoide']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['bienbuen', 'dara', 'trabajarse', 'comunitario', '', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['building', 'calidadnada', 'gentil', 'trabajarse', 'especialidad', 'cuba', 'eticacomo', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['building', 'capacitar', 'relacionamento', 'mecanica', 'dejaria', 'clarsmente', 'enfocarse', 'inicio', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['solonperfeccion', 'escucharla', 'gentil', 'siempremente', 'queria', 'soluble', 'masaje', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nexo', 'hechado', 'ofender', 'italia', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['recibirnos', 'traton', 'pocoy', 'etilo', '', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['ninguno', 'cascadee', 'corrupción', 'felicitarles', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nivelar', 'eticocobrarle', 'primo', 'link', 'directo', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['conocerian', 'casoodebrech', 'tips', 'trabajarse', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['conocerian', 'casoodebrech', 'tips', 'relacionarme', 'empresacon', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['conocerian', 'eventros', 'etilo', 'companias', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['conocerian', 'ninguno', 'cascadee', 'corrupción', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['creible', 'lealtad', 'menoscabar', 'mobbing', 'regional', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['creible', 'casoodebrech', 'corrupción', 'tan', 'fraudulento', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['ehscuchado', 'escucharla', 'vestuario', 'situações', 'eticasademas', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['ehscuchado', 'vestuario', 'ninguno', 'cascadee', 'corrupción', 'empresacon', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['estabecidos', 'involucrarse', 'proveedorcliente', 'casosemejante', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['vestuario', 'escucharla', 'algunasos', 'cascadee', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['vestuario', 'saberla', 'casoodebrech', 'asia', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['momentum', 'presenciarlo', 'embarquei', 'sial', 'hacercan', 'dudoso', 'hacerlo', 'saberla', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['conocerian', 'ninguno', 'cascadee', 'tips', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'empresacon', 'involucrarse', 'problemael', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'aunar', 'problemael', 'corrupción', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'casoodebrech', 'tips', 'menoscabar', 'recordarle', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'comentariosdejan', 'presenciarlo', 'asia', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'comentariosdejan', 'tan', 'presenciarlo', 'actor', 'etilo', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'casoodebrech', 'institucional', 'exceptuar', 'operacional', 'herramienta', 'abiertamente', 'granel', 'retener', 'citacion']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'ninguno', 'cascadee', 'excepcion', 'senala', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'debia', 'comunicarlos', 'masaje', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'relacionarme', 'tips', 'actor', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'nao', 'leio', 'temho', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'ninguno', 'comentariosdejan', 'indolecia', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'presenciarlo', 'cascadee', 'fraudulento', 'corrupción', 'significativo', 'existira', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'presenciarlo', 'cascadee', 'anticipacion', 'corrupción', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'vestuario', 'casoodebrech', 'pocoy', 'etilo', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'situações', 'enmendar', 'prestigiopara', 'eticocobrarle', 'institucional', 'solonperfeccion', 'experientes', 'medidcas', 'apurar']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'casoodebrech', 'pocoy', 'etilo', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['evidenciarlo', 'casoodebrech', 'etilo', 'aeromocas', 'feddback', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['presenciarlo', 'escucharla', 'casoodebrech', 'corrupción', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['presenciarlo', 'tan', 'escucharla', 'casoodebrech', 'corrupción', 'empresacon', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['recibirnos', 'comentariosdejan', 'respectfully', 'poderia', 'opinion', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['saberla', 'medioambiental', 'comunicacional', 'actor', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['conosco', 'pocoy', 'eticacomo', 'copecs', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['oportunidaded', 'presenciarlo', 'situações', 'eticasademas', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'involucrarse', 'casoodebrech', 'etilo', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['recomendación', 'culpable', 'maquinazos', 'transcurso', 'evitaria', 'suponer', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['constituir', 'haberlo', 'escucharla', 'vestuario', 'involucrarse', 'empresacon', 'directo', 'casoodebrech', 'repercutio', 'publicidad']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['constituir', 'problemael', 'alguns', 'material', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['tocaria', 'nungun', 'vera', 'casoodebrech', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nino', 'aunque', 'estancar', 'bajarlos', 'luz', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nooo', 'escucharla', 'presenciarlo', 'situações', 'descuadre', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['realista', 'hacercan', 'sede', 'nungun', 'escucharla', 'fraudulento', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'empresacon', 'problemael', 'conducto', 'eticasademas', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['confrontacional', 'igualar', 'pasarfue', 'acabar', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['vera', 'noticiero', 'relacionarme', 'empresacon', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['superar', 'eticocobrarle', 'escucharla', 'empresacon', 'serlo', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['antecesor', 'algunasos', 'cascadee', 'reportaria', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['antecesor', 'qe', 'parecia', 'bienbuen', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['conosco', 'existira', 'problemael', 'tips', 'empresacon', 'felicitarles', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['informacionen', 'respectfully', 'parecia', 'building', 'eticacomo', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['notable', 'hechado', 'ofender', 'complejo', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['contrario', 'empresacon', 'eticacomo', 'profesionalesabusos', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'ehscuchado', 'vestuario', 'asia', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'escucharla', 'asia', 'esperaria', 'asia', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'escucharla', 'casoodebrech', 'corrupción', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'escucharla', 'maltartos', 'institucional', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'escucharla', 'ninguno', 'comentariosdejan', 'negligencia', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'escucharla', 'vestuario', 'maltartos', 'empresacon', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'escucharla', 'malabar', 'comentariosdejan', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'escucharla', 'menoscabar', 'presenciarlo', 'actor', 'tips', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'problemael', 'tips', 'empresacon', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'oportunidaded', 'vera', 'situações', 'tips', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'vestuario', 'escucharla', 'casoodebrech', 'etilo', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'vestuario', 'presenciarlo', 'actor', 'etilo', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'vestuario', 'situacions', 'asia', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'informarlo', 'semenstrales', 'institucional', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'vestuario', 'enfrentarlas', 'tenerlos', 'enfrentarlas', 'algunasos', 'cascadee', 'tips', 'conocerian', 'existira']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nungun', 'mostrarle', 'gestion', 'preocupante', '', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['estancar', 'tributariamente', 'canalizar', 'respecto', 'realizardichostrabajos', 'denunciarlo', 'sial', 'gentil', 'hacercan', 'seran']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['personalfalta', 'profesionalesabusos', 'solicitos', 'cotizar', 'licitador', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['personalfalta', 'manifestarse', 'anticipacion', 'corrupção', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['esforçados', 'despota', 'evitaria', 'tips', 'conducto', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['momentum', 'escucharla', 'algunasos', 'fraudulento', 'momentum', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['trabajarse', 'area', 'realizardichostrabajos', 'evitaria', 'tips', 'situações', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['investigaciòn', 'probablemente', 'confundir', 'cariar', 'informarlo', 'ertico', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['atencionnunca', 'dara', 'paciencia', 'hacerlo', 'mejoramiento', 'estadistica', 'mierda', 'hospotales', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['partner', 'conocerian', 'ninguno', 'cascadee', 'felicitarles', 'empresacon', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['oidono', 'casoodebrech', 'quedarme', 'inconducente', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['preferitismo', 'base', 'david', 'concur', 'costa', 'decirle', 'ahime', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['presnciar', 'hablaria', 'casoodebrech', 'estresada', 'laboraleslo', 'verde', 'cualidad', 'buscarla', 'manerann', 'vulneraveis']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['dejaria', 'coluidos', 'demasiar', 'beneficencia', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['canalizar', 'denunciarlo', 'clarsmente', 'disposicion', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['trabajadorasa', 'cargarlo', 'combustiblesoy', 'quedarme', 'dios', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['masaje', 'explosion', 'decirle', 'problemael', 'clientela', 'valorarlas', 'verdade', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['relacao', 'building', 'servicion', 'clientela', 'mejoraria', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['atar', 'rapidamernte', 'cascadee', 'sucedio', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'emplearos', 'hacercan', 'tranparencia', 'entregarlos', 'combustiblesoy', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['detener', 'tiempoa', 'parecia', 'bienbuen', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['implementarlo', 'sistematicamente', 'controlador', 'altura', 'estandares', 'internalicen', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['lograrlas', 'detener', 'masaje', 'alguns', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['trabajarse', 'capar', 'colaborar', 'reportaria', 'oposicion', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['practicos', 'frecuentar', 'eticacomo', 'cadena', 'diabetes', 'mejoraria', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['realizardichostrabajos', 'encuetro', 'confluir', 'interesarse', 'curso', 'prevencionista', 'delos', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['saberla', 'desvincular', 'ventaja', 'indecopi', 'segurudad', 'afecto', 'afiliarse', 'final', 'buscarla', 'bienbuen']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['vera', 'imagenes', 'clinicas', 'corrupción', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['sial', 'consciencia', 'vera', 'empresacon', 'eticacomo', 'respectfully', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['sial', 'mesero', 'vendedor', 'aguilera', 'autoafiliacion', 'alcohol', 'llegasemos', 'esquinzar', 'mortal', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['siempremente', 'debera', 'sera', 'reportaria', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['siempremente', 'existira', 'casoodebrech', 'etilo', 'tomarle', 'medjora', 'correspondia', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['siempremente', 'comunicarlos', 'sial', 'existira', 'transparentea', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['siempremente', 'tratarlos', 'masaje', 'altura', 'nina', 'eticacomo', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['siempremente', 'reportaria', 'transan', 'monton', 'altura', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['siempremente', 'solucionarla', 'problemael', 'formal', '', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['sial', 'estacionesno', 'comunal', 'pagar', 'hurto', 'mia', 'combustiblesoy', 'aguilera', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['sentirce', 'existira', 'building', 'acomodar', 'hacian', 'personalfalta', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['comentariosdejan', 'siempremente', 'sera', 'bastar', 'legalidad', 'transparentarla', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['conosco', 'algunasos', 'cascadee', 'corrupción', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['sial', 'masaje', 'costa', 'dios', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['sial', 'eticocobrarle', 'encontrarlos', 'presentarse', 'problemael', 'personalfalta', 'encontrarlos', 'justicia', 'obviamente', 'nino']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['involucrarse', 'escandolo', 'american', 'vera', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['solonperfeccion', 'vestuario', 'casoodebrech', 'unilateral', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['solonperfeccion', 'felicitar', 'eticocobrarle', 'ejelente', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['solonperfeccion', 'escucharla', 'cuestionar', 'administrar', 'vestuario', 'cambii', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['solonperfeccion', 'vestuario', 'reclamostambien', 'rededor', 'socializar', 'sial', 'resquicio', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['solonperfeccion', 'dibulgar', 'precioseria', 'exagerar', 'altura', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['solonperfeccion', 'violentar', 'solucionarla', 'oportunidaded', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['saberla', 'llevarme', 'bienbuen', 'temho', 'colusionen', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['tenerlos', 'instante', 'poderia', 'reportarse', 'excepcion', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['entenderan', 'existira', 'areas', 'especialmente', 'temho', 'parecia', 'bienbuen', 'entelino', 'preocuparase', 'generaria']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['cascadee', 'reportaria', 'totalidad', 'responsabilizar', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['ola', 'caracterizarlos', 'sera', 'empresacon', 'serlo', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['casoodebrech', 'negligencia', 'aclararlos', 'juventud', 'medjora', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['casoodebrech', 'etilo', 'sera', 'informarlo', 'momentum', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['trabajadorasa', 'eticacomo', 'momentum', 'desempeno', 'funcionario', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['trabajoesta', 'realizardichostrabajos', 'colaborar', 'correspondia', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['vezes', 'trabajadorasa', 'queria', 'enganarme', 'salidad', 'cupula', 'electronico', 'avião', 'gerenciajefaturaempleados', 'solucionarla']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['yerba', 'this', 'demorar', 'thsi', 'ina', 'duena', 'cpd', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['creible', 'sera', 'descuento', 'sandra', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['building', 'organizacional', 'juramentar', 'vedar', 'organizacional', 'nulo', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Integridad
# Para texto: ['confluir', 'colusionen', 'confrontacional', 'papeleo', 'titular', 'llamarme', 'acabar', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Integridad
# Para texto: ['malabar', 'manejarse', 'comites', 'adminostrativos', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Integridad
# Para texto: ['muchoste', 'menos', 'caoticos', 'presenciarlo', 'respectfully', 'restaurant', 'suedos', '', '', '']
# El valor Predicho es Integridad Y deberia ser Integridad
# Para texto: ['presenciarlo', 'ninguno', 'hacercan', 'naturalmente', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Integridad
# Para texto: ['partir', 'relacionarme', 'politizar', 'zonal', 'siempremente', 'compostura', 'alumno', 'cargarlo', '', '']
# El valor Predicho es Integridad Y deberia ser Integridad
# Para texto: ['avda', 'integrador', 'ambos', 'paliativo', '', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Integridad
# Para texto: ['momentum', 'contrariocuando', 'acepto', 'unrespectful', 'situações', 'indecopi', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Integridad
# Para texto: ['hacercan', 'comunitario', 'hacercan', 'presenciarlo', 'residir', 'alegar', 'entornar', 'presentarse', 'costa', 'indecopi']
# El valor Predicho es Integridad Y deberia ser Integridad
# Para texto: ['nungun', 'vestuario', 'vulneraveis', 'eticacomo', 'mallar', 'plazo', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['poderia', 'notarse', 'cumpliran', 'estirar', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['entenderan', 'prioridad', 'establecerse', 'codigos', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['quehacer', 'establecerse', 'contratarlos', 'clarsmente', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['siempremente', 'tratarlos', 'amable', 'respetesiento', 'clientela', 'incognita', 'alterações', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['building', 'tratarlos', 'amablea', 'correcton', '', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Integridad
# Para texto: ['building', 'tratarlos', 'generalizar', 'companertos', 'jefea', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Integridad
# Para texto: ['correcton', 'acorde', 'cargarlo', 'ocurranpara', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Integridad
# Para texto: ['excepcion', 'tratarlos', 'respetesiento', 'cercano', '', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Integridad
# Para texto: ['ninguno', 'comentariosdejan', 'hacercan', 'puntoal', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Integridad
# Para texto: ['siempremente', 'ira', 'tratarlos', 'adecusdo', 'cordialidad', 'cadena', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Integridad
# Para texto: ['building', 'tratarlos', 'jefea', 'localizar', '', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Integridad
# ...
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['generalizar', 'comunicacional', 'transparentarla', 'filtrarse', 'canalizar', 'oficialmente', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['generalizar', 'casoodebrech', 'maltartos', 'imagenes', 'aspecto', 'todosporq', 'isaprescolusion', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['rancagua', 'existira', 'comites', 'eticacomo', 'acogida', 'cuan', 'consultor', 'dudoso', 'inquilino', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['realista', 'hacercan', 'vision', 'casoodebrech', 'asia', 'haberlo', 'empresacon', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['pasarfue', 'hombre', 'legalidad', 'eacuchado', 'bastar', 'tiempoa', 'casilla', 'mesar', 'imagenes', 'directo']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'vendian', 'gasolina', 'facultad', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['necesidad', 'fortalecimiento', 'link', 'comunicacional', 'denunciarlo', 'respectfully', 'caoticos', 'contribuir', 'frecuencia', 'generaria']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['comuna', 'reportaria', 'canalizar', 'disposicion', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['estancar', 'favorable', 'segurudad', 'complemento', 'importancia', 'tiempoa', 'conrespecto', 'segurudad', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['debera', 'mejoraria', 'sobrevenden', 'areas', 'ventaja', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['dependiente', 'jefaturacon', 'recibirnos', 'informacionen', '', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['oportunidaded', 'personasbasandose', 'compor', 'processos', 'debera', 'demostraria', 'eticacomo', 'compromisso', 'clientela', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['oportunidaded', 'mejoraria', 'tenerlos', 'sistematicamente', 'confiablesa', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['existira', 'cifrar', 'nivelar', 'transparenciade', 'aunar', 'quehacer', 'mejoraria', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['falência', 'comunicarlos', 'personalfalta', 'odiar', 'funcionarior', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['falência', 'fiscalización', 'trabajoesta', 'mantenedor', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['falência', 'difundirlas', 'empresacon', 'prestamo', 'servicion', 'crecer', 'procedimientoa', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['falência', 'informacionen', 'estan', 'denucia', 'consciencia', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['falência', 'informarlo', 'cascadee', 'formulacion', 'clarsmente', 'evitaria', 'comentariosdejan', 'pasion', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['falência', 'masaje', 'eticacomo', 'temho', 'socializar', 'ambientar', 'educacional', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['falência', 'revisión', 'constantemente', 'arenar', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['falência', 'supervisor', 'proceso', 'atencionnunca', 'pacientepero', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['falência', 'vera', 'masaje', 'falsificar', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['formulacion', 'clarsmente', 'manejable', 'medioambiental', 'dara', 'trabajoesta', 'contrato', 'elementar', 'mejorsr', 'masaje']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['fraudulento', 'cobsultorio', 'costa', 'innesariamente', 'cobrarle', 'recaudacion', 'utilizarla', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['generaria', 'procedimientoa', 'operatorio', 'estandares', 'processos', 'modulod', 'vera', 'desviandose', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['hacercan', 'revison', 'periodicidad', 'arenar', 'manejarse', 'acto', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['despistar', 'manejarse', 'atesorar', 'dios', 'empresacon', 'eticacomo', 'profesionalesabusos', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['momentum', 'ninguno', 'comentariosdejan', 'sera', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['conducto', 'eticasademas', 'queria', 'abordarse', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['jefea', 'gerentesafortunadamente', 'nafa', 'saberla', 'estancar', 'ocurranpara', 'llegasemos', 'amigote', 'algun', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['preferencial', 'cifrar', 'contratistasno', 'realizardichostrabajos', 'trabajarse', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['hacercan', 'poderia', 'volvio', 'odiar', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'chilectra', 'original', 'companias', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['problemael', 'guardiad', 'seguridadcamaras', 'especificos', 'momentum', 'entregar', 'descartar', 'insulto', 'malabar', 'tratarlos']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['vestuario', 'huerfanos', 'puerto', 'baladron', 'suero', 'trabajadorasa', 'deberiamos', 'pasarfue', 'sial', 'cobrarle']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['igualdadya', 'horario', 'gestionesya', 'equipar', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['indebidad', 'masaje', 'relacionamento', 'distribuiodres', 'altura', 'ejelente', 'empresacon', 'evitaria', 'casoodebrech', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['inventario', 'cuan', 'motivarlo', 'diagnosticos', 'operario', 'pad', 'esperaria', 'seguiran', 'esperaria', 'trabajarse']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['jefea', 'mejoramiento', 'prepotencia', 'cargarlo', 'desempenar', 'esperaria', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['convivir', 'cifrar', 'gentil', 'trabajarse', '', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['corrupción', 'falência', 'eticacomo', 'vera', 'favoristismo', 'ocurrio', 'sistematicamente', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['empresacon', 'exigirles', 'cafe', 'fraudulento', 'contribuir', 'pequena', 'saberla', 'dejaria', 'cafe', 'solonperfeccion']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['eticacomo', 'servicion', 'dejaria', 'esperaria', 'gentil', 'salsa', 'horario', 'ofrecernos', 'servicion', 'dessa']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['eticacomo', 'sial', 'sera', 'medjora', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['link', 'eticacomo', 'parecia', 'segurudad', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['lamentablemrten', 'sug', 'contaminación', 'isaprescolusion', 'abundalo', 'ganar', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['empresacon', 'utilizarla', 'tips', 'artisticos', 'enganarme', 'soborno', 'psicologia', 'laboraleslo', 'noto', 'enfermedad']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['personasbasandose', 'cargp', 'suficientemente', 'detener', 'anomalidad', 'hacercan', 'esperaria', 'emplearos', 'menos', 'jerarquias']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['lavarse', 'imagenes', 'eticacomo', 'explotar', 'personalfalta', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['verdade', 'desconocido', 'sial', 'casoodebrech', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['exigirles', 'ventaja', 'bcp', 'promoveria', 'instaurar', 'engano', 'afianzar', 'contratación', 'bcp', 'tanque']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['cobsultorio', 'excesivod', 'estacionamientosevitar', 'cobrarle', 'acorde', 'tiempoa', 'costumbre', 'atencionnunca', 'cambiario', 'sistematicamente']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['unicos', 'duenos', 'mismodia', 'confrontacional', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mantenien', 'masaje', 'pendite', 'casoodebrech', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['masaje', 'comunicacional', 'manejable', 'medioambiental', 'superioresjefes', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['masaje', 'trabajarse', 'equiparar', 'mejoraria', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mayoria', 'controlador', 'personasbasandose', 'relacionamento', 'areas', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mayoria', 'informacionen', 'partner', 'empresacon', 'mediar', 'correr', 'personalfalta', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mejoraria', 'seguir', 'cumpliran', 'reglamento', 'internet', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mejoraria', 'difusión', 'sistematicamente', 'anticorrupicion', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mejoraria', 'eticacomo', 'empresacon', 'mostrarle', 'demasy', 'favoritismosque', 'trabajadorasa', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mejoraria', 'orientar', 'frequentes', 'imprimir', 'cmp', 'dirigir', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['mejoraria', 'canalizar', 'finalidad', 'filtrarse', 'informacionen', 'igualar', 'deberiamos', 'sera', 'asia', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mejoraria', 'plano', 'carretara', 'colaborar', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mejoraria', 'plano', 'costumbre', 'servicion', 'clientela', 'poderia', 'competitive', 'empresacon', 'igualar', 'rubromuy']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mejoraria', 'empresacon', 'asegurar', 'ponerlo', 'mudança', 'cadena', 'pisco', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['mejoramiento', 'controlador', 'doc', 'trabajarse', 'doc', 'pagarles', 'jose', 'laboraleslo', 'ordwn', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['parecia', 'profesionalesabusos', 'cascadee', 'atenderlo', 'apuro', 'mirarme', 'cascadee', 'dele', 'ganarian', 'masaje']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['robarme', 'periodica', 'lugar', 'tal', 'valios', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['negativamente', 'tratandome', 'eticocobrarle', 'clarasfaciles', 'interesarse', 'pacientepero', 'solonperfeccion', 'paginar', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['ausencia', 'siempremente', 'building', 'atesorar', '', '', '', '', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['conocerian', 'derecchos', 'encarnizamiento', 'areas', 'encontrarlos', 'importar', 'tenerlos', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['conocerian', 'temho', 'nungun', 'informarlo', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['contratarlos', 'gentil', 'venoso', 'antecesor', 'pasarfue', 'oportunidaded', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'pacientepero', 'escucharla', 'solonperfeccion', 'partner', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['conosco', 'canalizar', 'oficialmente', 'casoodebrech', 'etilo', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['respetesiento', 'asig', 'resguardar', 'sera', 'entregarlos', 'funcionarior', 'amigote', 'lancargo', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['canalizar', 'difusión', 'comunicacional', 'temho', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['nino', 'medjora', 'reciclar', 'ningubo', 'formulacion', 'proteger', 'mediaticamente', 'ambienterespeto', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'respectfully', 'cascadee', 'corrupción', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['escucharla', 'creible', 'qe', 'estereotipo', 'involucrarse', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['saberla', 'tips', 'casoodebrech', 'dara', 'conocerian', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# Para texto: ['casoodebrech', 'directoa', 'renombre', 'eticacomo', 'podriamos', 'dara', 'retroalimentación', 'itens', '', '']
# El valor Predicho es Integridad Y deberia ser Anti-corrupción
# Para texto: ['constituir', 'posibilidad', 'informacionen', 'respectfully', '', '', '', '', '', '']
# El valor Predicho es Anti-corrupción Y deberia ser Anti-corrupción
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-113-4bc49a131e36> in <module>
#       1 for i in range(len(predictions)):
# ----> 2     print('Para texto:', [vocabulary[item] for item in X_completo[valores_testeo][i]])
#       3     print('El valor Predicho es', list_dimensions[predictions[i]], 'Y deberia ser', list_dimensions[y_completo[valores_testeo][i]])
#
# <ipython-input-113-4bc49a131e36> in <listcomp>(.0)
#       1 for i in range(len(predictions)):
# ----> 2     print('Para texto:', [vocabulary[item] for item in X_completo[valores_testeo][i]])
#       3     print('El valor Predicho es', list_dimensions[predictions[i]], 'Y deberia ser', list_dimensions[y_completo[valores_testeo][i]])
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt
history_dict = history.history
acc = history_dict['sparse_categorical_accuracy']
loss = history_dict['loss']
epochs = range(1, len(acc) + 1)
# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig("../Imagenes/RNN/GOB/T&V_loss_GOB_1.png")

# %%
plt.clf()
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.savefig("../Imagenes/RNN/GOB/T&V_acc_GOB_1.png")

# %%
import sklearn.metrics as metrics

fpr, tpr, threshold = metrics.roc_curve(y_completo[valores_testeo], predictions)
roc_auc = metrics.auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig("../Imagenes/RNN/GOB/ROC_GOB_1.png")
