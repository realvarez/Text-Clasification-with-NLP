# %%
import pandas as pd
import nltk
import tensorflow as tf

import collections
import math
import os
import sys
import argparse
import random
from tempfile import gettempdir
import zipfile

# %%
data = pd.read_csv("Data/Flujo1.csv", sep=";")
data
# Out:
#                   Area                Dimension  \
# 0       Medio Ambiente    Comunidad (Ambiental)
# 1       Medio Ambiente    Comunidad (Ambiental)
# 2       Medio Ambiente    Comunidad (Ambiental)
# 3       Medio Ambiente    Comunidad (Ambiental)
# 4       Medio Ambiente    Comunidad (Ambiental)
# 5       Medio Ambiente    Comunidad (Ambiental)
# 6       Medio Ambiente    Comunidad (Ambiental)
# 7       Medio Ambiente    Comunidad (Ambiental)
# 8       Medio Ambiente    Comunidad (Ambiental)
# 9       Medio Ambiente    Comunidad (Ambiental)
# 10      Medio Ambiente    Comunidad (Ambiental)
# 11      Medio Ambiente    Comunidad (Ambiental)
# 12      Medio Ambiente    Comunidad (Ambiental)
# 13      Medio Ambiente    Comunidad (Ambiental)
# 14      Medio Ambiente    Comunidad (Ambiental)
# 15      Medio Ambiente    Comunidad (Ambiental)
# 16      Medio Ambiente    Comunidad (Ambiental)
# 17      Medio Ambiente    Comunidad (Ambiental)
# ...
