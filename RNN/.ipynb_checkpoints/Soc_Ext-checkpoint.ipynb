# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import ast
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from tensorflow.keras.preprocessing.sequence import pad_sequences
import seaborn as sns
#from google.colab import drive
#drive.mount('/content/drive/')  
tf.__version__
# Out:
# '1.15.0'

# %%
#df = pd.read_csv('drive/My Drive/Tesis/Data/Flujo1.csv', sep=";")
df = pd.read_csv('../Data/Flujo1.csv', sep=";")

df['Respuesta'] = df['Respuesta'].apply(ast.literal_eval)

def enumerate_dimensions(dimension, list_dimensions): 
    return list_dimensions.index(dimension)

def wordsToNumbers(tokens, vocabulary):
    number_array = []
    for i in tokens:
        number_array.append(vocabulary.index(i)+1)
    return np.asarray(number_array)

# %%
# Se Construye Dataframe solo de Social Externo
df = df[df.Area == 'Social Externo']

# Lista de dimensiones se pasa a numeros
list_dimensions = df.Dimension.unique().tolist()
num_classes = len(list_dimensions)
df['_dimension'] = df['Dimension'].apply(enumerate_dimensions, list_dimensions = list_dimensions)

#Generamos un vocabulario de palabras
vocabulary = []
df['Respuesta'].apply(vocabulary.append)
vocabulary = [item for sublist in vocabulary for item in sublist]
vocabulary = list(set(vocabulary))

# %%
df['NumRespuesta'] = df.Respuesta.apply (wordsToNumbers, vocabulary = vocabulary)
# Rellenamos las matrices con 0 para que todas tengan el mismo tamaño
X_completo = pad_sequences(df.NumRespuesta, maxlen=10, dtype='object', padding='post', value = 0)

# Pasamos las dimensiones a np array
y_completo = np.array(df['_dimension'])

X, test_x, y, test_y = train_test_split(X_completo, y_completo, test_size = 0.2, random_state = 0)

# %%
kf = KFold(n_splits = 10, shuffle = True, random_state = 2)
resultados = []
contador = 1
for valores_entrenamiento, valores_testeo in kf.split(X):
    model = tf.keras.Sequential()
    #Se agrega capa embedding que hace w2v
    model.add(tf.keras.layers.Embedding(input_dim=len(vocabulary) + 1, output_dim = 100, input_shape=(X_completo.shape[1],)))
    model.add(tf.keras.layers.LSTM(units=90, activation='sigmoid'))
    model.add(tf.keras.layers.Dense(units=14, activation='sigmoid'))
    model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])
    history = model.fit(X_completo, y_completo, epochs = 150, batch_size=15)
    print()
    print(contador, '-Resultados con datos de testeo ')
    print()
    test_loss, test_acurracy = model.evaluate(X[valores_testeo], y[valores_testeo])
    print()
    print(contador, '-Data Test accuracy: {}'.format(test_acurracy))
    resultados.append(test_acurracy)
    print()
    predictions = model.predict_classes(X[valores_testeo])
    #Matriz de confusion
    confusion = tf.confusion_matrix(labels=y[valores_testeo], predictions= predictions, dtype=tf.dtypes.int32, num_classes=14)
    print(contador, '-Matriz de confusion')
    print(confusion.eval(session=tf.Session()))
    print()
    contador = contador + 1
# Out:
# WARNING:tensorflow:From D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\keras\initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 69463 samples
# Epoch 1/150
# 69463/69463 [==============================] - 78s 1ms/sample - loss: 1.8493 - sparse_categorical_accuracy: 0.4014
# Epoch 2/150
# 69463/69463 [==============================] - 78s 1ms/sample - loss: 1.4093 - sparse_categorical_accuracy: 0.5450
# Epoch 3/150
# 69463/69463 [==============================] - 78s 1ms/sample - loss: 1.3118 - sparse_categorical_accuracy: 0.5743
# Epoch 4/150
# 69463/69463 [==============================] - 78s 1ms/sample - loss: 1.2543 - sparse_categorical_accuracy: 0.5931
# Epoch 5/150
# 69463/69463 [==============================] - 78s 1ms/sample - loss: 1.2120 - sparse_categorical_accuracy: 0.6079
# Epoch 6/150
# 69463/69463 [==============================] - 76s 1ms/sample - loss: 1.1779 - sparse_categorical_accuracy: 0.6206
# Epoch 7/150
# 69463/69463 [==============================] - 76s 1ms/sample - loss: 1.1449 - sparse_categorical_accuracy: 0.6312
# Epoch 8/150
# 69463/69463 [==============================] - 76s 1ms/sample - loss: 1.1179 - sparse_categorical_accuracy: 0.6417
# Epoch 9/150
# 69463/69463 [==============================] - 82s 1ms/sample - loss: 1.0873 - sparse_categorical_accuracy: 0.6538
# Epoch 10/150
# 69463/69463 [==============================] - 85s 1ms/sample - loss: 1.0636 - sparse_categorical_accuracy: 0.6616
# Epoch 11/150
# 69463/69463 [==============================] - 87s 1ms/sample - loss: 1.0417 - sparse_categorical_accuracy: 0.6711
# Epoch 12/150
# 69463/69463 [==============================] - 83s 1ms/sample - loss: 1.0207 - sparse_categorical_accuracy: 0.6789
# Epoch 13/150
# 69463/69463 [==============================] - 83s 1ms/sample - loss: 1.0029 - sparse_categorical_accuracy: 0.6853
# Epoch 14/150
# 69463/69463 [==============================] - 80s 1ms/sample - loss: 0.9840 - sparse_categorical_accuracy: 0.6912
# Epoch 15/150
# 69463/69463 [==============================] - 81s 1ms/sample - loss: 0.9715 - sparse_categorical_accuracy: 0.6972
# Epoch 16/150
# 69463/69463 [==============================] - 82s 1ms/sample - loss: 0.9556 - sparse_categorical_accuracy: 0.7014
# Epoch 17/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.9420 - sparse_categorical_accuracy: 0.7080
# Epoch 18/150
# 69463/69463 [==============================] - 82s 1ms/sample - loss: 0.9286 - sparse_categorical_accuracy: 0.7138
# Epoch 19/150
# 69463/69463 [==============================] - 85s 1ms/sample - loss: 0.9173 - sparse_categorical_accuracy: 0.7175
# Epoch 20/150
# 69463/69463 [==============================] - 84s 1ms/sample - loss: 0.9034 - sparse_categorical_accuracy: 0.72162s - loss: 0.9018
# Epoch 21/150
# 69463/69463 [==============================] - 85s 1ms/sample - loss: 0.8925 - sparse_categorical_accuracy: 0.7253
# Epoch 22/150
# 69463/69463 [==============================] - 82s 1ms/sample - loss: 0.8812 - sparse_categorical_accuracy: 0.7295
# Epoch 23/150
# 69463/69463 [==============================] - 82s 1ms/sample - loss: 0.8689 - sparse_categorical_accuracy: 0.7340
# Epoch 24/150
# 69463/69463 [==============================] - 80s 1ms/sample - loss: 0.8582 - sparse_categorical_accuracy: 0.7365
# Epoch 25/150
# 69463/69463 [==============================] - 84s 1ms/sample - loss: 0.8461 - sparse_categorical_accuracy: 0.7412
# Epoch 26/150
# 69463/69463 [==============================] - 89s 1ms/sample - loss: 0.8325 - sparse_categorical_accuracy: 0.74541s - loss: 0.8328 - sparse_categorical
# Epoch 27/150
# 69463/69463 [==============================] - 87s 1ms/sample - loss: 0.8230 - sparse_categorical_accuracy: 0.7489
# Epoch 28/150
# 69463/69463 [==============================] - 83s 1ms/sample - loss: 0.8126 - sparse_categorical_accuracy: 0.7507
# Epoch 29/150
# 69463/69463 [==============================] - 83s 1ms/sample - loss: 0.8003 - sparse_categorical_accuracy: 0.7563
# Epoch 30/150
# 69463/69463 [==============================] - 77s 1ms/sample - loss: 0.7882 - sparse_categorical_accuracy: 0.7598
# Epoch 31/150
# 69463/69463 [==============================] - 76s 1ms/sample - loss: 0.7790 - sparse_categorical_accuracy: 0.7641
# Epoch 32/150
# 69463/69463 [==============================] - 82s 1ms/sample - loss: 0.7680 - sparse_categorical_accuracy: 0.7676
# Epoch 33/150
# 69463/69463 [==============================] - 82s 1ms/sample - loss: 0.7570 - sparse_categorical_accuracy: 0.7715
# Epoch 34/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.7456 - sparse_categorical_accuracy: 0.7745
# Epoch 35/150
# 69463/69463 [==============================] - 86s 1ms/sample - loss: 0.7380 - sparse_categorical_accuracy: 0.7773
# Epoch 36/150
# 69463/69463 [==============================] - 85s 1ms/sample - loss: 0.7274 - sparse_categorical_accuracy: 0.7808
# Epoch 37/150
# 69463/69463 [==============================] - 85s 1ms/sample - loss: 0.7143 - sparse_categorical_accuracy: 0.7842
# Epoch 38/150
# 69463/69463 [==============================] - 88s 1ms/sample - loss: 0.7073 - sparse_categorical_accuracy: 0.78640s - loss: 0.7075 - sparse_categorical_accu
# Epoch 39/150
# 69463/69463 [==============================] - 87s 1ms/sample - loss: 0.6949 - sparse_categorical_accuracy: 0.79202s - loss: 0.6944 -
# Epoch 40/150
# 69463/69463 [==============================] - 89s 1ms/sample - loss: 0.6857 - sparse_categorical_accuracy: 0.79412s - loss: 0.6
# Epoch 41/150
# 69463/69463 [==============================] - 87s 1ms/sample - loss: 0.6768 - sparse_categorical_accuracy: 0.7960
# Epoch 42/150
# 69463/69463 [==============================] - 86s 1ms/sample - loss: 0.6657 - sparse_categorical_accuracy: 0.7995
# Epoch 43/150
# 69463/69463 [==============================] - 90s 1ms/sample - loss: 0.6572 - sparse_categorical_accuracy: 0.8033
# Epoch 44/150
# 69463/69463 [==============================] - 87s 1ms/sample - loss: 0
# 69463/69463 [==============================] - 133s 2ms/sample - loss: 0.3299 - sparse_categorical_accuracy: 0.9063s - loss: 0.3298 - sparse_cate
# Epoch 113/150
# 69463/69463 [==============================] - 135s 2ms/sample - loss: 0.3304 - sparse_categorical_accuracy: 0.9062
# Epoch 114/150
# 69463/69463 [==============================] - 133s 2ms/sample - loss: 0.3271 - sparse_categorical_accuracy: 0.9079
# Epoch 115/150
# 69463/69463 [==============================] - 129s 2ms/sample - loss: 0.3263 - sparse_categorical_accuracy: 0.9075s - ETA: 3s - loss: 0.3254 - sparse_categorical_accuracy: 0.90 - ETA: 3s -
# Epoch 116/150
# 69463/69463 [==============================] - 121s 2ms/sample - loss: 0.3262 - sparse_categorical_accuracy: 0.9081
# Epoch 117/150
# 69463/69463 [==============================] - 127s 2ms/sample - loss: 0.3211 - sparse_categorical_accuracy: 0.9093s - loss:
# Epoch 118/150
# 69463/69463 [==============================] - 127s 2ms/sample - loss: 0.3185 - sparse_categorical_accuracy: 0.9098
# Epoch 119/150
# 69463/69463 [==============================] - 104s 1ms/sample - loss: 0.3174 - sparse_categorical_accuracy: 0.9098
# Epoch 120/150
# 69463/69463 [==============================] - 83s 1ms/sample - loss: 0.3171 - sparse_categorical_accuracy: 0.91042s - loss: 0
# Epoch 121/150
# 69463/69463 [==============================] - 82s 1ms/sample - loss: 0.3143 - sparse_categorical_accuracy: 0.9113
# Epoch 122/150
# 69463/69463 [==============================] - 88s 1ms/sample - loss: 0.3169 - sparse_categorical_accuracy: 0.9105
# Epoch 123/150
# 69463/69463 [==============================] - 87s 1ms/sample - loss: 0.3143 - sparse_categorical_accuracy: 0.9117
# Epoch 124/150
# 69463/69463 [==============================] - 90s 1ms/sample - loss: 0.3126 - sparse_categorical_accuracy: 0.91151s - loss: 0.3128 - spa
# Epoch 125/150
# 69463/69463 [==============================] - 82s 1ms/sample - loss: 0.3094 - sparse_categorical_accuracy: 0.91261s - loss: 0.3090 - sparse_categ
# Epoch 126/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.3098 - sparse_categorical_accuracy: 0.9127
# Epoch 127/150
# 69463/69463 [==============================] - 78s 1ms/sample - loss: 0.3079 - sparse_categorical_accuracy: 0.9135
# Epoch 128/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.3091 - sparse_categorical_accuracy: 0.9138
# Epoch 129/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.3050 - sparse_categorical_accuracy: 0.9145
# Epoch 130/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.3037 - sparse_categorical_accuracy: 0.9144
# Epoch 131/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.3071 - sparse_categorical_accuracy: 0.9135
# Epoch 132/150
# 69463/69463 [==============================] - 78s 1ms/sample - loss: 0.3043 - sparse_categorical_accuracy: 0.9140
# Epoch 133/150
# 69463/69463 [==============================] - 78s 1ms/sample - loss: 0.2995 - sparse_categorical_accuracy: 0.9155
# Epoch 134/150
# 69463/69463 [==============================] - 78s 1ms/sample - loss: 0.3034 - sparse_categorical_accuracy: 0.9154
# Epoch 135/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.2974 - sparse_categorical_accuracy: 0.9154
# Epoch 136/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.2933 - sparse_categorical_accuracy: 0.9162
# Epoch 137/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.2969 - sparse_categorical_accuracy: 0.9165
# Epoch 138/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.2980 - sparse_categorical_accuracy: 0.9167
# Epoch 139/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.2990 - sparse_categorical_accuracy: 0.9173
# Epoch 140/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.2971 - sparse_categorical_accuracy: 0.9183
# Epoch 141/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.2944 - sparse_categorical_accuracy: 0.9180
# Epoch 142/150
# 69463/69463 [==============================] - 78s 1ms/sample - loss: 0.2947 - sparse_categorical_accuracy: 0.9167
# Epoch 143/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.2950 - sparse_categorical_accuracy: 0.9177
# Epoch 144/150
# 69463/69463 [==============================] - 78s 1ms/sample - loss: 0.2910 - sparse_categorical_accuracy: 0.9185
# Epoch 145/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.2897 - sparse_categorical_accuracy: 0.9180
# Epoch 146/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.2950 - sparse_categorical_accuracy: 0.9184
# Epoch 147/150
# 69463/69463 [==============================] - 78s 1ms/sample - loss: 0.2930 - sparse_categorical_accuracy: 0.9182
# Epoch 148/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.2890 - sparse_categorical_accuracy: 0.9194
# Epoch 149/150
# 69463/69463 [==============================] - 79s 1ms/sample - loss: 0.2856 - sparse_categorical_accuracy: 0.9203
# Epoch 150/150
# 69463/69463 [==============================] - 78s 1ms/sample - loss: 0.2902 - sparse_categorical_accuracy: 0.9188
#
# 1 -Resultados con datos de testeo
#
# 5557/5557 [==============================] - 0s 55us/sample - loss: 0.2673 - sparse_categorical_accuracy: 0.9244
#
# 1 -Data Test accuracy: 0.924419641494751
#
# 1 -Matriz de confusion
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#
# D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#
# D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#
# InvalidArgumentError: assertion failed: [`labels` out of bound] [Condition x < y did not hold element-wise:] [x (confusion_matrix/control_dependency:0) = ] [1 13 5...] [y (confusion_matrix/Cast:0) = ] [2]
# 	 [[{{node confusion_matrix/assert_less/Assert/AssertGuard/Assert}}]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-5-e0efe4392661> in <module>
#      22     confusion = tf.confusion_matrix(labels=y[valores_testeo], predictions= predictions, dtype=tf.dtypes.int32, num_classes=2)
#      23     print(contador, '-Matriz de confusion')
# ---> 24     print(confusion.eval(session=tf.Session()))
#      25     print()
#      26     contador = contador + 1
#
# D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\framework\ops.py in eval(self, feed_dict, session)
#     796
#     797     """
# --> 798     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     799
#     800   def experimental_ref(self):
#
# D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\framework\ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    5405                        "the tensor's graph is different from the session's "
#    5406                        "graph.")
# -> 5407   return session.run(tensors, feed_dict)
#    5408
#    5409
#
# D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1382                     '\nsession_config.graph_options.rewrite_options.'
#    1383                     'disable_meta_optimizer = True')
# -> 1384       raise type(e)(node_def, op, message)
#    1385
#    1386   def _extend_graph(self):
#
# InvalidArgumentError: assertion failed: [`labels` out of bound] [Condition x < y did not hold element-wise:] [x (confusion_matrix/control_dependency:0) = ] [1 13 5...] [y (confusion_matrix/Cast:0) = ] [2]
# 	 [[node confusion_matrix/assert_less/Assert/AssertGuard/Assert (defined at D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\framework\ops.py:1748) ]]
#
# Original stack trace for 'confusion_matrix/assert_less/Assert/AssertGuard/Assert':
#   File "D:\ProgramasVarios\Anaconda\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "D:\ProgramasVarios\Anaconda\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\ipykernel\kernelapp.py", line 563, in start
#     self.io_loop.start()
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tornado\platform\asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "D:\ProgramasVarios\Anaconda\lib\asyncio\base_events.py", line 534, in run_forever
#     self._run_once()
#   File "D:\ProgramasVarios\Anaconda\lib\asyncio\base_events.py", line 1771, in _run_once
#     handle._run()
#   File "D:\ProgramasVarios\Anaconda\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\ipykernel\kernelbase.py", line 378, in dispatch_queue
#     yield self.process_one()
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tornado\gen.py", line 225, in wrapper
#     runner = Runner(result, future, yielded)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tornado\gen.py", line 714, in __init__
#     self.run()
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\ipykernel\kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\ipykernel\kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 2855, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in _run_cell
#     return runner(coro)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 3058, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 3249, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-e0efe4392661>", line 22, in <module>
#     confusion = tf.confusion_matrix(labels=y[valores_testeo], predictions= predictions, dtype=tf.dtypes.int32, num_classes=2)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\ops\confusion_matrix.py", line 261, in confusion_matrix_v1
#     name)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\ops\confusion_matrix.py", line 176, in confusion_matrix
#     labels, num_classes_int64, message='`labels` out of bound')],
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\ops\check_ops.py", line 879, in assert_less
#     summarize, message, name)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\ops\check_ops.py", line 371, in _binary_assert
#     return control_flow_ops.Assert(condition, data, summarize=summarize)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\util\tf_should_use.py", line 198, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs))
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\ops\control_flow_ops.py", line 173, in Assert
#     guarded_assert = cond(condition, no_op, true_assert, name="AssertGuard")
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\ops\control_flow_ops.py", line 1235, in cond
#     orig_res_f, res_f = context_f.BuildCondBranch(false_fn)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\ops\control_flow_ops.py", line 1061, in BuildCondBranch
#     original_result = fn()
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\ops\control_flow_ops.py", line 171, in true_assert
#     condition, data, summarize, name="Assert")
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\ops\gen_logging_ops.py", line 74, in _assert
#     name=name)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\framework\op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\framework\ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\framework\ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "D:\ProgramasVarios\Anaconda\lib\site-packages\tensorflow_core\python\framework\ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()

# %%
test_loss
# Out:
# 0.2673129855819544
